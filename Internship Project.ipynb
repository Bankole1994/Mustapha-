# %% [markdown]
# ## Data Science Job Salary
# Data science jobs are some of the fastest-growing, most in-demand in technology. Since 2012, Data Scientist roles have increased by 650 percent, and this rise shows no sign of stopping. The U.S. Bureau of Labor Statistics predicts that the demand for data science skills will increase another 27.9 percent by 2026. And, according to a report from McKinsey, that spells a shortage of between 140,000 and 190,000 people with analytical skills in the U.S. alone—not to mention another 1.5 million managers and analysts who will be required to understand how data analysis drives decision-making.
#
# Data Scientist salaries have also risen with demand; Data Scientists can typically expect to make six figures. Demand also translates into an ability to relocate far more easily—from city to city, and even internationally.

# %% [markdown]
# ### Feature Description
# * work_year - The year the salary was paid.
# * Experience level - The experience level in the job during the year with the following possible values: EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director
# * Emploment type - The type of employement for the role: PT Part-time FT Full-time CT Contract FL Freelance
# * Job title - The role worked in during the year.
# * Salary - The total gross salary amount paid.
# * Salary in Usd - The total gross salary amount paid in USD
# * Salary Currency - The currency of the salary paid as an ISO 4217 currency code.
# * Employee Residence Employee's primary country of residence in during the work year as an ISO 3166 country code.
# * Remote ratio - The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
# * Company Location - The country of the employer's main office or contracting branch as an ISO 3166 country code.
# * Company Size - The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)

# %%
# impoting neccassary library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing my data
df = pd.read_csv('salary.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# renaming the unnamame column
df.rename( columns={'Unnamed: 0':'employee_id'}, inplace=True ) 
df.head()
# Out:
#    employee_id  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.describe().T
# Out:
#                count           mean           std     min      25%       50%  \
# employee_id    607.0     303.000000  1.753701e+02     0.0    151.5     303.0
# work_year      607.0    2021.405272  6.921330e-01  2020.0   2021.0    2022.0
# salary         607.0  324000.062603  1.544357e+06  4000.0  70000.0  115000.0
# salary_in_usd  607.0  112297.869852  7.095726e+04  2859.0  62726.0  101570.0
# remote_ratio   607.0      70.922570  4.070913e+01     0.0     50.0     100.0
#
#                     75%         max
# employee_id       454.5       606.0
# work_year        2022.0      2022.0
# salary         165000.0  30400000.0
# salary_in_usd  150000.0    600000.0
# remote_ratio      100.0       100.0

# %%
# minimum salary in usd
df['salary_in_usd'].unique()
# Out:
# array([ 79833, 260000, 109024,  20000, 150000,  72000, 190000,  35735,
#        135000, 125000,  51321,  40481,  39916,  87000,  85000,   8000,
#         41689, 114047,   5707,  56000,  43331,   6072,  47899,  98000,
#        115000, 325000,  42000,  33511, 100000, 117104,  59303,  70000,
#         68428, 450000,  46759,  74130, 103000, 250000,  10000, 138000,
#         45760,  50180, 106000, 112872,  15966,  76958, 188000, 105000,
#         70139,  91000,  45896,  54742,  60000, 148261,  38776, 118000,
#        120000, 138350, 110000, 130800,  21669, 412000,  45618,  62726,
#         49268, 190200,  91237,  42197,  82528, 235000,  53192,   5409,
#        270000,  80000,  79197, 140000,  54238,  47282, 153667,  28476,
#         59102, 170000,  88654,  76833,  19609, 276000,  29751,  89294,
#         12000,  95746,  75000,  36259,  62000,  73000,  51519, 187442,
#         30428,  94564, 113476, 103160,  45391, 225000,  50000,  40189,
# ...

# %%
# maximum salary in usd
df['salary_in_usd'].max()
# Out:
# 600000

# %%
sns.boxplot(y='salary_in_usd',data=df)
plt.show()

# %%
sns.boxplot(y='remote_ratio',data=df)
plt.show()

# %%
plt.figure(figsize=(9,8))
plt.title('experience_level')
sns.countplot(x='experience_level', data=df)
plt.xlabel('experience_level')
plt.ylabel('Count of experience_level')
plt.show()

# %%
plt.figure(figsize=(20,15))
df['job_title'].value_counts().plot.barh()
plt.title('Job Title')
# Out:
# Text(0.5, 1.0, 'Job Title')

# %% [markdown]
# #### Thie chart show that Data Scientist highest job demand follow by Data Engineer and Data Analyst while Data Analyst Lead is least job demand.

# %%
df['company_location'].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
plt.figure(figsize=(20,15))
df['salary_currency'].value_counts().plot.barh()
plt.title('salary currency')

# %% [markdown]
# #### This show USD is the highest currency use in paying employee salary follow by Euro, and pounds, while CHF is the least currency use in paying employee.

# %%
plt.figure(figsize=(9,8))
df['job_title'].value_counts()[:10].plot.barh()
plt.title('Job Title')
# Out:
# Text(0.5, 1.0, 'Job Title')

# %%
us_job = df[df['company_location']=='US']['job_title'].value_counts()[:10]
us_job.plot(kind='barh',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### This plot shows the top 10 highest demand job in USA, which Data Engineer is highest as the highest. follow by Data Scientist and Data Analyst, while Analytics Engineer is the 10th job demand in USA

# %%
plt.figure(figsize=(20,15))
df['employee_residence'].value_counts().plot.barh()
plt.title('Empolyee Residence')
# Out:
# Text(0.5, 1.0, 'Empolyee Residence')

# %% [markdown]
# #### This Graph shows, USA has the highest employee residence follow by United Kingdom and India.

# %%
plt.figure(figsize=(9,8))
plt.title('Employment Type')
sns.countplot(x='employment_type', data=df)
plt.xlabel('employment_type')
plt.ylabel('Count of employment_type')
plt.show()

# %% [markdown]
# #### This graph show Full time employee is the highest emploment type, follow the Contract staff and Freelacer is the least emploment type

# %%
plt.figure(figsize=(20,8))
plt.title('Company Location')
sns.countplot(x='company_location', data=df)
plt.xlabel('Company Location')
plt.ylabel('Count of Company Location')
plt.show()

# %% [markdown]
# #### US has the highest number of job location, follow by United Kingdom and Canada

# %%
plt.figure(figsize=(9,8))
df['work_year'].value_counts().plot.pie(autopct='%.2f')
plt.title('Work Year')
# Out:
# Text(0.5, 1.0, 'Work Year')

# %% [markdown]
# #### This show there is increase in employee demand.

# %%
fig, ax1 = plt.subplots(figsize = (10, 8))
viz = sns.countplot(ax=ax1, x="company_size", data=df)
viz.set_xticklabels(viz.get_xticklabels(), rotation=90)
for i in viz.patches:
    height = i.get_height()
    viz.text(i.get_x() + i.get_width()/2., height + 0.1, height, ha="center")
plt.title("Company Size")
plt.ylabel("Count of Company Size")
# Out:
# Text(0, 0.5, 'Count of Company Size')

# %% [markdown]
# #### The Meadium Size company has larger employee follow by Large company size, while the Small Company as the least.

# %%
employment_experience_pivot = pd.crosstab(df.employment_type,df.experience_level,normalize='index')

employment_experience_pivot.plot.bar(stacked=True, figsize=(15,8))

plt.title('Emploment Type by Experience Level')
plt.show()

# %% [markdown]
# #### This graph represent Emploment Type by Experience , the Contract staff and Full time emploment has all Experience Level, while Freelancer and Part-time has only two experience level

# %%
companySize_experience_pivot = pd.crosstab(df.company_size,df.experience_level,normalize='index')

companySize_experience_pivot.plot.bar(stacked=True, figsize=(15,8))

plt.title('Company Size by Experience Level')
plt.show()

# %% [markdown]
# #### The graph represent the company size by experience level, which show all company as all the experience level

# %%
jobTitle_experience_pivot = pd.crosstab(df.job_title,df.experience_level,normalize='index')

jobTitle_experience_pivot.plot.bar(stacked=True, figsize=(20,25))

plt.title('Job Title by Experience Level')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# #### The chart show job title by experience

# %%
companyLolation_experience_pivot = pd.crosstab(df.company_location,df.experience_level,normalize='index')

companyLolation_experience_pivot.plot.bar(stacked=True, figsize=(20,25))

plt.title('Company Location by Experience Level')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# #### This chart show Company location by experience level

# %%
df.salary_in_usd = df.salary_in_usd.astype(float)
salary_list = list(df['experience_level'].unique())
salary_ratio = []
for i in salary_list:
    x = df[df['experience_level']==i]
    salary_rate = sum(x.salary_in_usd)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt .figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.title('Salary by Experience Level')
plt.show()

# %% [markdown]
# #### This graph show that Expact level has the highest Salaries, follow by Senior Entry, while Entry level is the least Salaries

# %%
sns.barplot(x='work_year', y='salary_in_usd',data=df)
plt.title('Salary by Year')
plt.show()

# %% [markdown]
# #### 2022 has the highest paid salaries

# %%
sns.barplot(x='work_year', y='remote_ratio',data=df)
plt.title('Work year by remote ratio')
plt.show()

# %%
df.salary_in_usd = df.salary_in_usd.astype(float)
salary_list = list(df['company_size'].unique())
salary_ratio = []
for i in salary_list:
    x = df[df['company_size']==i]
    salary_rate = sum(x.salary_in_usd)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt .figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('company_size')
plt.ylabel('Salary')
plt.title('Salary by Company Size')
plt.show()

# %% [markdown]
# #### Large company has the highest salary while small company is the least

# %%
df[['remote_ratio', 'salary_in_usd']]
df[['remote_ratio', 'salary_in_usd']].groupby(['remote_ratio'], as_index= False).mean().sort_values(by= 'salary_in_usd', ascending= False).plot.barh()
plt.title('hhh')
plt.show()

# %%
df.salary_in_usd = df.salary_in_usd.astype(float)
salary_list = list(df['job_title'].unique())
salary_ratio = []
for i in salary_list:
    x = df[df['job_title']==i]
    salary_rate = sum(x.salary_in_usd)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt.figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Job Title')
plt.ylabel('Salary')
plt.title('Salary by Job Title')
plt.show()

# %% [markdown]
# #### This show,  Data Anayst lead is the highest paid, follow by principal data engineer and financial data analyst, while 3D computer vision is the least paid job.

# %%
df.salary_in_usd = df.salary_in_usd.astype(float)
salary_list = list(df['company_location'].unique())
salary_ratio = []
for i in salary_list:
    x = df[df['company_location']==i]
    salary_rate = sum(x.salary_in_usd)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt.figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Company Location')
plt.ylabel('Salary')
plt.title('Top 10 Salary by Company Location')
plt.show()

# %% [markdown]
# ### Conclusion
# ####  Data Science is a great field due to increase in demand from the data we observed, the ideal job in data science field are Data engineer, Data Scientist and Data Analyst, for entry level employee, data scientist and data analyst is the best field to look into, and for you to have a good salary, you need to increase your experience level, the higher your experience the higher you earn.
# #### The US is the fastest growing country in the field of data science, having the highest skilled employee, Company and employee residence.
# #### They are many job role in data science, the most of demand  is data scientist.
